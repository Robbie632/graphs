# %%
import json

with open('out2.json', 'r') as fp:
    obj = json.load(fp)

# %%
data = pd.read_json('out2.json')

# %%
import pandas as pd

# %%
annotations = obj['RELEASE']['annolist']

# %%
annotations[600]
# Out:
# {'image': {'name': '016893506.jpg'},
#  'annorect': {'x1': 888,
#   'y1': 99,
#   'x2': 1012,
#   'y2': 224,
#   'annopoints': {'point': [{'x': 944, 'y': 511, 'id': 6, 'is_visible': 1},
#     {'x': 989, 'y': 232, 'id': 7, 'is_visible': 1},
#     {'x': 984.0917, 'y': 223.1273, 'id': 8, 'is_visible': None},
#     {'x': 915.9083, 'y': 99.8727, 'id': 9, 'is_visible': None},
#     {'x': 921, 'y': 843, 'id': 0, 'is_visible': 1},
#     {'x': 922, 'y': 712, 'id': 1, 'is_visible': 1},
#     {'x': 895, 'y': 506, 'id': 2, 'is_visible': 1},
#     {'x': 992, 'y': 516, 'id': 3, 'is_visible': 1},
#     {'x': 972, 'y': 724, 'id': 4, 'is_visible': 1},
#     {'x': 961, 'y': 933, 'id': 5, 'is_visible': 1},
#     {'x': 773, 'y': 399, 'id': 10, 'is_visible': 1},
#     {'x': 857, 'y': 377, 'id': 11, 'is_visible': 1},
#     {'x': 901, 'y': 238, 'id': 12, 'is_visible': 1},
#     {'x': 1076, 'y': 226, 'id': 13, 'is_visible': 1},
#     {'x': 1121, 'y': 359, 'id': 14, 'is_visible': 1},
# ...

# %%
df = pd.DataFrame(annotations)

# %%
df.iloc[600]['annorect']
# Out:
# {'x1': 888,
#  'y1': 99,
#  'x2': 1012,
#  'y2': 224,
#  'annopoints': {'point': [{'x': 944, 'y': 511, 'id': 6, 'is_visible': 1},
#    {'x': 989, 'y': 232, 'id': 7, 'is_visible': 1},
#    {'x': 984.0917, 'y': 223.1273, 'id': 8, 'is_visible': None},
#    {'x': 915.9083, 'y': 99.8727, 'id': 9, 'is_visible': None},
#    {'x': 921, 'y': 843, 'id': 0, 'is_visible': 1},
#    {'x': 922, 'y': 712, 'id': 1, 'is_visible': 1},
#    {'x': 895, 'y': 506, 'id': 2, 'is_visible': 1},
#    {'x': 992, 'y': 516, 'id': 3, 'is_visible': 1},
#    {'x': 972, 'y': 724, 'id': 4, 'is_visible': 1},
#    {'x': 961, 'y': 933, 'id': 5, 'is_visible': 1},
#    {'x': 773, 'y': 399, 'id': 10, 'is_visible': 1},
#    {'x': 857, 'y': 377, 'id': 11, 'is_visible': 1},
#    {'x': 901, 'y': 238, 'id': 12, 'is_visible': 1},
#    {'x': 1076, 'y': 226, 'id': 13, 'is_visible': 1},
#    {'x': 1121, 'y': 359, 'id': 14, 'is_visible': 1},
#    {'x': 1095, 'y': 537, 'id': 15, 'is_visible': 1}]},
#  'scale': 4.225704202,
# ...
